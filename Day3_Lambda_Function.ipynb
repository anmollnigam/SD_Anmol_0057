# %% [markdown]
# <a href="https://colab.research.google.com/github/anmollnigam/SD_Anmol_0057/blob/main/Day3_Lambda_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=3
p=2

# %%
def test(n,p):
  return n**p

# %%
test(3,2)
# Out:
# 9

# %%
a= lambda n ,p : n**p

# %%
a(3,5)
# Out:
# 243

# %%
a = lambda m,n,o,p : m+n+o+p

# %%
a(2,5,6,8)
# Out:
# 21

# %%
c_to_f = lambda c : (9/5)*c+32

# %%
c_to_f(45)
# Out:
# 113.0

# %%
f_to_c = lambda f: ((f-32)*5)/9

# %%
f_to_c(65)
# Out:
# 18.333333333333332

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(9,10)
# Out:
# 10

# %%
finding_min = lambda x,y : x if x<y else y

# %%
finding_min(26,35)
# Out:
# 26

# %%
s="Anmol"

# %%
find_len = lambda s : len(s)

# %%
find_len(s)
# Out:
# 5

# %%
find_min = lambda x,y,z : x if (x<y)and(x<z)  else ( y if (y<x) and (y<z) else z)

# %%
find_min(3,5,2)
# Out:
# 2

# %%
l = [2,3,4,5,6]

# %%
def test(l):
  l1=[]
  for i in l:
    l1.append(i**2)
  return l1

# %%
test(l)
# Out:
# [4, 9, 16, 25, 36]

# %%
l
# Out:
# [2, 3, 4, 5, 6]

# %%
def sq(x):
  return x**2

# %%
list(map(sq,l))
# Out:
# [4, 9, 16, 25, 36]

# %%
list (map(lambda x : x**2,l))
# Out:
# [4, 9, 16, 25, 36]

# %%
l1 = [1,2,3,4,5]
l2 = [6,7,8,9,10]
list(map(lambda x,y : x+y,l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
def add(x,y):
  return x+y

# %%
list(map(add,l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
def mul(x,y):
  return x*y

# %%
list(map(mul,l1,l2))
# Out:
# [6, 14, 24, 36, 50]

# %%
s = "skills"
list(map(lambda s : s.upper(),s))
# Out:
# ['S', 'K', 'I', 'L', 'L', 'S']

# %%
from functools import reduce

# %%
l=[1,2,3,4,5]

# %%
reduce(lambda x,y : x+y,l)
# Out:
# 15

# %%
reduce(lambda x,y,z : x+y+z,l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_29603/2669847218.py in <cell line: 0>()
# ----> 1 reduce(lambda x,y,z : x+y+z,l)
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
reduce(lambda x,y : x+y,[1])
# Out:
# 1

# %%
reduce(lambda x,y : x*y,l)
# Out:
# 120

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
reduce(lambda x,y : x if x>y else y,l)
# Out:
# 5
