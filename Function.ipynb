# %% [markdown]
# <a href="https://colab.research.google.com/github/anmollnigam/SD_Anmol_0057/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test1():
   pass

# %%
def test1():
  print("this is my first function")

# %%
test1()
# Out:
# this is my first function

# %%
test1() + "ankit"

# %%
def test2():
  return "this is my first function call "

# %%
test2() + " ankit"
# Out:
# 'this is my first function call ankit'

# %%
def test3():
  return "sudh",23,453,45.6,[23,4,2,]

# %%
test3()
# Out:
# ('sudh', 23, 453, 45.6, [23, 4, 2])

# %%
a,b,c,d,e =test3()

# %%
a
# Out:
# 'sudh'

# %%
def test4():
  u = 5+6/7
  return u

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d = a+b/c
  return d

# %%
test5(2,5,7)
# Out:
# 2.7142857142857144

# %%
def test6(a,b):
  return a+b

# %%
test6(8,9.8)
# Out:
# 17.8

# %%
test6("Anmol","Nigam")
# Out:
# 'AnmolNigam'

# %%
test6([2,5,8,6,5] , [5,6,8])
# Out:
# [2, 5, 8, 6, 5, 5, 6, 8]

# %%
test6({2,5,8,6,5} , {5,6,8})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12485/2035992198.py in <cell line: 0>()
# ----> 1 test6({2,5,8,6,5} , {5,6,8})
#
# /tmp/ipykernel_12485/2790025198.py in test6(a, b)
#       1 def test6(a,b):
# ----> 2   return a+b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
l = [1,2,3,4,"sudh","Kumar",[1,2,3,4,5,6]]

# %%
l1 = []
for i in l :
  if type(i) == int or type(i) == float :
    l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
def test8(a) :
   l= []
   for i in a :
    if(type(i) == list):
      for j in i :
        l.append(j)
    else :
      if type(i) == int or type(i) == float:
        l.append(i)
    return l

# %%
test8(l)
# Out:
# [1]

# %%
print(" Calculator")
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
print("Enter the operator you want to perform")
ch=input("Enter any of these char for specific operation +,-,*,/:")
def Calculator(num1,num2,ch):
  result=0
  if ch=='+':
    result=num1+num2
  elif ch=='-':
    result=num1-num2
  elif ch=='*':
    result=num1*num2
  elif ch=='/':
    result=num1/num2
  else:
    print("Input character is not recognized!")
  print(num1,ch,num2,":",result)
Calculator(num1,num2,ch)
# Out:
#  Calculator
# Enter the first number:1
# Enter the second number:2
# Enter the operator you want to perform
# Enter any of these char for specific operation +,-,*,/:+
# 1 + 2 : 3

# %%
print("Welcome to the ATM")
print("Please insert your card")
pin = int(input("Please enter your pin"))
print("Please select any provided services: ")
ch = input("Select any one service- 1.Deposit , 2. Withdrawl , 3. Balance Enquiry , 4. Mini Statement : ")
def ATM(pin):
  if(pin == 964824):
    if ch == '1':
      print("Deposit")
    elif ch == '2':
      print("Withdrawl")
    elif ch == '3':
      print("Balance Enquiry")
    elif ch == '4':
      print("Mini Statement")
    else:
      print("Invalid Input")
  else:
    print("Invalid Pin")
  print("Thank you for using ATM")
ATM(pin)
# Out:
# Welcome to the ATM
# Please insert your card
# Please enter your pin964824
# Please select any provided services:
# Select any one service- 1.Deposit , 2. Withdrawl , 3. Balance Enquiry , 4. Mini Statement : 2
# Withdrawl
# Thank you for using ATM

# %%
def test_fib1(n):
  a,b = 0,1
  for i in range(n):
    yield a
    a,b = b,a+b

# %%
for i in test_fib1(5):
  print(i)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
fib=test_fib1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12485/4260469332.py in <cell line: 0>()
# ----> 1 fib = test_fib1()
#       2 print(fib)
#
# NameError: name 'test_fib1' is not defined

# %%
s = "sudh"

# %%
for i in s:
  print(i)
# Out:
# s
# u
# d
# h

# %%
s
# Out:
# 'sudh'

# %%
next(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12485/1977886155.py in <cell line: 0>()
# ----> 1 next(s)
#
# TypeError: 'str' object is not an iterator
