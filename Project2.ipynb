# %% [markdown]
# <a href="https://colab.research.google.com/github/anmollnigam/SD_Anmol_0057/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Student Management System!")
print("Student's Scorecard")
Student_name= input("Enter Your Name : ");
print("Hello",Student_name);
Sybject_name1 = input("Enter 1st Subject name:");
m1 = int(input("Enter marks:"));
Sybject_name2 = input("Enter 2nd Subject name:");
m2 = int(input("Enter marks:"));
Sybject_name3 = input("Enter 3rd Subject name:");
m3 = int(input("Enter marks:"));
Sybject_name4 =input("Enter 4th Subject name:");
m4 = int(input("Enter marks:"));
Sybject_name5 = input("Enter 5th Subject name:");
m5 = int(input("Enter marks:"));

Total_marks = m1+m2+m3+m4+m5;
print("Total marks:",Total_marks);
Percentage = Total_marks/5;
print("Percentage:",Percentage);

if(Percentage>=90):
    print("Grade:A");
elif(Percentage>=80):
    print("Grade:B");
elif(Percentage>=70):
    print("Grade:C");
elif(Percentage>=60):
    print("Grade:D");
else{
    print("Fail");
}
# Out:
# Welcome to Student Management System!
# Student's Scorecard
# Enter Your NameAnmol
# Hello Anmol
# Enter 1st Subject name:DS
# Enter marks:98
# Enter 2nd Subject name:COA
# Enter marks:95
# Enter 3rd Subject name:DTL
# Enter marks:96
# Enter 4th Subject name:CY
# Enter marks:95
# Enter 5th Subject name:DA
# Enter marks:99
# Total marks: 483
# Percentage: 96.6
# Grade:A
